# %%
#from google.colab import auth
#auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 형태소분석기 관련 설치
# !apt-get update
# !apt-get install g++ openjdk-8-jdk

# !pip install JPype1
# !pip install rhinoMorph
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# ...

# %%
# 경로 변경
# %cd /content/gdrive/My\ Drive/pytest/
# Out:
# /content/gdrive/My Drive/pytest

# %%
# !ls
# Out:
# data		 newfile2.txt  ratings_morphed.txt  wiki_test.txt
# income.csv	 newfile.csv   ratings_small.txt
# income_test.csv  positive.txt  ratings.txt
# negative.txt	 pos.txt       test.csv

# %%
# 데이터 로딩
def read_data(filename, encoding='cp949'):                # 읽기 함수 정의
  with open(filename, 'r', encoding=encoding) as f:
    data = [line.split('\t') for line in f.read().splitlines()]
    #리스트 컴프리핸션 => 각 줄을 읽어서 컬럼 단위로 나눔. 근데 이해가 어려움.

    data = data[1:]                 # txt 파일의 헤더(id document label)는 제외하기
  return data

def write_data(data, filename, encoding='cp949'):         # 쓰기 함수도 정의
  with open(filename, 'w', encoding=encoding) as f:
    f.write(data)

#data = read_data('/content/gdrive/My Drive/pytest/ratings_small.txt', encoding='cp949')
data = read_data('pos.txt', encoding='utf8')  # 전체파일은 ratings.txt 



#내가 머신러닝이나 딥러닝 할 떄 맞추는 것은 0과 1 중에서 1임.

# %%
# data 내용 형태소 분석
import rhinoMorph
rn = rhinoMorph.startRhino()
with open('pos_test.txt', 'w', encoding='utf-8') as f:
    for data_each in data:
        morphed_data_each = rhinoMorph.onlyMorph_list(rn, data_each[0], pos=['NNG', 'NNP', 'NP', 'VV', 'VA', 'VX', 'XR', 'IC', 'MM', 'MAG'], eomi=False)
        print("morphed_data_each:", morphed_data_each)
        joined_data_each = ' '.join(morphed_data_each)
        if joined_data_each:
            f.write(joined_data_each + '\t' + data_each[1] + '\n')
    print('Morphological Analysis Completed.')
# Out:
# filepath:  /usr/local/lib/python3.7/dist-packages
# classpath:  /usr/local/lib/python3.7/dist-packages/rhinoMorph/lib/rhino.jar
# RHINO started!
# morphed_data_each: ['흥미']
# morphed_data_each: ['재미있']
# morphed_data_each: ['거역']
# morphed_data_each: ['알']
# morphed_data_each: ['싫']
# morphed_data_each: ['가로막']
# morphed_data_each: ['가로지르']
# Morphological Analysis Completed.

# %%
# 감정사전 읽기
positive = read_data('pos_test.txt',encoding='utf-8')		      # 긍정 감정사전 읽기
print("positive:", positive)

                     
pos_found = []                                # 각 문장에서 발견될 긍정어의 개수 
neg_found = []                                # 각 문장에서 발견될 부정어의 개수
# Out:
# positive: [['재미있', '1'], ['거역', '0'], ['알', '1'], ['싫', '0'], ['가로막', '0'], ['가로지르', '0']]
